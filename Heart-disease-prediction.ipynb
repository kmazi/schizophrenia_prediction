# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("Schizhophrenia_latest.csv")

# %%
dataset.head()
# Out:
#    S/N  Hospital_Number   Age  Gender level_of_education  \
# 0    1         103282.0  35.0     1.0                  3
# 1    2         103301.0  40.0     1.0                  1
# 2    3         103183.0  25.0     1.0                  3
# 3    4         103063.0  35.0     2.0                  4
# 4    5        1442019.0  43.0     2.0                  4
#
#   Duration_of_Symtoms(months) EXCESS_WRITING  TALKING_TO_SELF  \
# 0                          30              1              1.0
# 1                          12            NaN              1.0
# 2                         120            NaN              NaN
# 3                           5            NaN              1.0
# 4                         156            NaN              1.0
#
#    WANDERING_AIMLESSLY  AGGRESSIVENESS  ...  Short_Memory  Long_Memory  \
# 0                  NaN             NaN  ...           1.0          3.0
# 1                  1.0             NaN  ...           1.0          1.0
# ...

# %%
dataset.describe()
# Out:
#               S/N  Hospital_Number         Age      Gender  TALKING_TO_SELF  \
# count  170.000000     1.350000e+02  164.000000  168.000000             37.0
# mean    85.500000     5.280174e+05   32.963415    1.470238              1.0
# std     49.218899     4.506485e+05   11.778576    0.500606              0.0
# min      1.000000     2.556000e+03    2.000000    1.000000              1.0
# 25%     43.250000     1.030960e+05   25.000000    1.000000              1.0
# 50%     85.500000     5.328890e+05   31.500000    1.000000              1.0
# 75%    127.750000     8.815200e+05   39.000000    2.000000              1.0
# max    170.000000     3.162012e+06   80.000000    2.000000              1.0
#
#        WANDERING_AIMLESSLY  AGGRESSIVENESS  ISOLATION  POOR_SELF_CARE  \
# count                 45.0            47.0        8.0            41.0
# mean                   1.0             1.0        1.0             1.0
# std                    0.0             0.0        0.0             0.0
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170 entries, 0 to 169
# Data columns (total 74 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   S/N                          170 non-null    int64
#  1   Hospital_Number              135 non-null    float64
#  2   Age                          164 non-null    float64
#  3   Gender                       168 non-null    float64
#  4   level_of_education           148 non-null    object
#  5   Duration_of_Symtoms(months)  151 non-null    object
#  6   EXCESS_WRITING               3 non-null      object
#  7   TALKING_TO_SELF              37 non-null     float64
#  8   WANDERING_AIMLESSLY          45 non-null     float64
#  9   AGGRESSIVENESS               47 non-null     float64
#  10  ISOLATION                    8 non-null      float64
#  11  POOR_SELF_CARE               41 non-null     float64
# ...

# %%
dataset1 = dataset.drop(labels=["EXCESS_WRITING","TALKING_TO_SELF","WANDERING_AIMLESSLY", "AGGRESSIVENESS",
    "ISOLATION","POOR_SELF_CARE","ABNORMAL BEHAIVOUR","LACK_OF_SLEEEP","DISTRUCTIVE","INCREASE__ENERGY",
     "LAUGHING_ALONE","LOW_ENERGY","OBSSESSION","POOR__EYE_CONTACT","GOING_NAKED","MUTE","RESTLESS",
    "TALKS_OUT_OF_POINT","FALSE_ACCUSATION","GESTICULATING","STOPPED_SCHOOL","WITHDRAWN","POOR_APPETITE",
    "HEARING_VOICES","AFRIAD_OF_OTHERS","SEEING_THINGS","SUICIDAL_THOUGHT","TALKING_TO_UNSEEN_PEOPLE",
     "IRRITABLE","SHAKING","FORGETFULNESS","CUTTING SELF","CRYING SPELL","POSTURING","CHILDISHNESS","BEGGING FOR FOGIVNESS",
     "COHERENT","RELEVANT","NORMAL_VOLUME_AND_TUNE","LOW_VOLUME_ TUNE",
     "MUTE.1","IRRATIONAL","ACCUSATRY","INCOHERENT","HIGH_PITCH","HESITANT","COPIOUS"], axis=1)
dataset1
# Out:
#      S/N  Hospital_Number   Age  Gender level_of_education  \
# 0      1         103282.0  35.0     1.0                  3
# 1      2         103301.0  40.0     1.0                  1
# 2      3         103183.0  25.0     1.0                  3
# 3      4         103063.0  35.0     2.0                  4
# 4      5        1442019.0  43.0     2.0                  4
# ..   ...              ...   ...     ...                ...
# 165  166          67855.0  53.0     1.0                  4
# 166  167           2556.0  30.0     2.0
# 167  168         767850.0  20.0     2.0                NaN
# 168  169         933252.0  39.0     1.0                NaN
# 169  170              NaN  23.0     1.0                  4
#
#     Duration_of_Symtoms(months)  Mood  Affect  Form_of_thought  \
# 0                            30   1.0     1.0              1.0
# 1                            12   2.0     2.0              1.0
# 2                           120   3.0     1.0              1.0
# ...

# %%
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170 entries, 0 to 169
# Data columns (total 27 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   S/N                          170 non-null    int64
#  1   Hospital_Number              135 non-null    float64
#  2   Age                          164 non-null    float64
#  3   Gender                       168 non-null    float64
#  4   level_of_education           148 non-null    object
#  5   Duration_of_Symtoms(months)  151 non-null    object
#  6   Mood                         160 non-null    float64
#  7   Affect                       160 non-null    float64
#  8   Form_of_thought              157 non-null    float64
#  9   Progression_of_Thought       152 non-null    float64
#  10  Possession_of_Thought        150 non-null    float64
#  11  Content_of_Thought           158 non-null    float64
# ...

# %%
dataset1["level_of_education"][dataset1["level_of_education"] != " "].value_counts()
# Out:
# 2     55
# 3     51
# 4     35
# 1      6
#        1
# Name: level_of_education, dtype: int64

# %%
dataset1.hist(figsize=(40,40))
plt.show()
